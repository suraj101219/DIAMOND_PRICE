# %%
##Diamond Price Prediction
Introduction About the Data :
The dataset The goal is to predict price of given diamond (Regression Analysis).

There are 10 independent variables (including id):

id : unique identifier of each diamond
carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
cut : Quality of Diamond Cut
color : Color of Diamond
clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
table : A diamond's table is the facet which can be seen when the stone is viewed face up.
x : Diamond X dimension
y : Diamond Y dimension
x : Diamond Z dimension
Target variable:

price: Price of the given Diamond.
Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z    price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619.0
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387.0
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772.0
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666.0
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453.0

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      1
# dtype: int64

# %%
### No missing values present in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103855 entries, 0 to 103854
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       103855 non-null  int64
#  1   carat    103855 non-null  float64
#  2   cut      103855 non-null  object
#  3   color    103855 non-null  object
#  4   clarity  103855 non-null  object
#  5   depth    103855 non-null  float64
#  6   table    103855 non-null  float64
#  7   x        103855 non-null  float64
#  8   y        103855 non-null  float64
#  9   z        103855 non-null  float64
#  10  price    103854 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 8.7+ MB

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z    price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619.0
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387.0
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772.0
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666.0
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453.0

# %%
## Lets drop the id column
df=df.drop(labels=['id'],axis=1)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z    price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619.0
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387.0
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772.0
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666.0
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453.0

# %%
## check for duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
## segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Categorical Columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   103855  103855  103855
# unique       5       7       8
# top      Ideal       G     SI1
# freq     49793   23744   28626

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        49793
# Premium      26600
# Very Good    20129
# Good          6264
# Fair          1069
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    23744
# E    19138
# F    18411
# H    16697
# D    13059
# I     9408
# J     3398
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     28626
# VS2     25691
# VS1     16503
# SI2     16263
# VVS2     8507
# VVS1     5666
# IF       2320
# I1        279
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
## Assignment Do the same for categorical data
 
## correlation
sns.heatmap(df[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
##Currently we will not execute this
## df.drop(labels=['x','y','z'],axis=1)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z    price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619.0
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387.0
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772.0
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666.0
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453.0

# %%
## https://www.americangemsociety.org/ags-diamond-grading-system/
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity'] = df['clarity'].map(clarity_map)
df['color'] = df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z    price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619.0
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387.0
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772.0
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666.0
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453.0
